# %%
from dataloader import *
from model import *
from train_eval_test import *
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 2024-01-12 15:28:02.409211: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-12 15:28:02.545428: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-12 15:28:04.625351: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.6/lib64:/usr/local/cuda-12.2/lib64
# 2024-01-12 15:28:04.625459: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.6/lib64:/usr/local/cuda-12.2/lib64
# 2024-01-12 15:28:04.625468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Load data

# %%
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)

# %%
weather_data = pd.read_csv('data/weather.csv', header=None).to_numpy()

# %%
batch_size = 32
n_train = 36792
n_eval = 5271
n_test = 10540
train_loader, eval_loader, test_loader = get_loaders(weather_data, batch_size, n_train, n_eval, n_test, T=96, S=96)

# %% [markdown]
# ## Train

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
#writer = SummaryWriter()
# Out:
# cuda

# %%
N = 21 #nb variables
T = 96 #input length (lookback window)
D = 512 # 256 ou 512
S = 96 # 96 ou 192, 336, 720
hidden_dim = 64
num_blocks = 2 #2 ou 3 ou 4 (nombre de block de transformer)

itransformer = iTransformer(N, T, D, S, hidden_dim, num_blocks).to(device)
optimizer = torch.optim.Adam(itransformer.parameters(), lr=5*1e-4, weight_decay=1e-5) #10−3, 5 × 10−4, 10−4

# %%
loss_values, loss_eval = train(itransformer, optimizer, train_loader, eval_loader, 10, device)
# Out:
# ---- epoch :  0
# loss train : 0.4954069210662983
# loss eval : 0.41886786537037957
# ---- epoch :  1
# loss train : 0.472210345612782
# loss eval : 0.38747070306613124
# ---- epoch :  2
# loss train : 0.4616255088276518
# loss eval : 0.38485432802527036
# ---- epoch :  3
# loss train : 0.46343288073720573
# loss eval : 0.3861436489739536
# ---- epoch :  4
# loss train : 0.45463101654179533
# loss eval : 0.4181748281842397
# ---- epoch :  5
# loss train : 0.46549684288663873
# loss eval : 0.3872412629885438
# Early stopping after 5 epochs without improvement.

# %%
plt.figure()
plt.plot(loss_values,label="Loss en train")
plt.plot(loss_eval,label="Loss en validation")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(loss_values,label="Loss en train")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(loss_eval,label="Loss en validation")
plt.legend()
plt.show()

# %% [markdown]
# ## Test

# %%
loss_test, loss_mae, target, yhat = test(itransformer, test_loader, device)
print("MSE : ", loss_test)
print("MAE : ", loss_mae)
# Out:
# MSE :  0.17579096285511314
# MAE :  0.21948678835214655

# %% [markdown]
# Affichage pour une modalité sur toute la durée de la prédiction

# %%
i = 1
plt.figure()
plt.plot(target[0,:,i].to("cpu"), "--", label="target")
plt.plot(yhat[0,:,i].to("cpu"),label="prediction")
plt.legend()
plt.show()

# %% [markdown]
# Affichage de toutes les modalités à un instant t

# %%
plt.figure()
plt.plot(target[0,0,:].to("cpu"), "--", label="target")
plt.plot(yhat[0,0,:].to("cpu"),label="prediction")
plt.legend()
plt.show()
